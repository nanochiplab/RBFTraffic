# %% [markdown]
# <a href="https://colab.research.google.com/github/nanochiplab/RBFTraffic/blob/main/OdevTraffic_RBFN_Gamma0_001_sgd_accu_sgd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

import os
from keras.utils import load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout,Activation,InputLayer,Layer

import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
#!git clone https://github.com/sonu275981/GTSRB---German-Traffic-Sign-Recognition
#cur_path= "GTSRB---German-Traffic-Sign-Recognition/gtsrb-german-traffic-sign/Train/"
# !git clone https://github.com/MohamedNennouche/German-Traffic-Sign-Recognition
cur_path= "German-Traffic-Sign-Recognition/Train/"
# Out:
# Cloning into 'German-Traffic-Sign-Recognition'...
# remote: Enumerating objects: 52027, done.
# remote: Total 52027 (delta 0), reused 0 (delta 0), pack-reused 52027 (from 1)
# Receiving objects: 100% (52027/52027), 300.65 MiB | 34.74 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Updating files: 100% (101736/101736), done.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#cur_path = "/content/drive/MyDrive/Mlp/Train"


data = []
labels = []
classes = 43  # Toplam sınıf sayısı

# Veri listeleri
X = []
y = []

print("")
print("Görüntüler Yükleniyor...")
print("************************........:")
print("")

# Görüntüleri yükleme

# Görüntüleri yükleme
for i in range(classes):
    path = os.path.join(cur_path, str(i))


    # Özyinelemeli olarak tüm dosyaları gez
    for root, dirs, files in os.walk(path):
        for file in files:
            try:
                image_path = os.path.join(root, file)

                # Görüntü dosyasını yükle ve işle
                image = Image.open(image_path)
                image = image.resize((30, 30))
                image = np.array(image)

                # Veri ve etiketleri ekle
                #data.append([image, i])
                data.append(image)
                labels.append(i)  # Etiketleri ayrı olarak ekleyin
            except Exception as e:
                print(f"Hata: Görüntü yüklenemedi. Dosya: {image_path}, Hata: {e}")

print(f"Toplam yüklenen görüntü sayısı: {len(data)}")
print("************************........:")

#x = []
#y = []
"""
X = []
y = []

for features,label in data:
    X.append(features)
    y.append(label)
"""
#Converting lists into numpy arrays
X = np.array(data)
y = np.array(labels)
# Out:
# Görüntüler Yükleniyor...
# ************************........:
#
# Toplam yüklenen görüntü sayısı: 39209
# ************************........:

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Layer, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Özel RBF katmanı tanımı
class RBFLayer(Layer):
    def __init__(self, num_units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.num_units = num_units
        self.gamma = gamma

    def build(self, input_shape):
        self.centers = self.add_weight(name='centers',
                                       shape=(self.num_units, input_shape[-1]),
                                       initializer='random_normal',
                                       trainable=True)
        self.built = True

    def call(self, inputs):
        # RBF fonksiyonu: exp(-gamma * ||inputs - centers||^2)
        diff = tf.expand_dims(inputs, axis=1) - self.centers
        sq_dist = tf.reduce_sum(tf.square(diff), axis=-1)
        return tf.exp(-self.gamma * sq_dist)

# Veriyi normalize etme ve sınıflara ayırma
X = X / 255.0  # Piksel değerlerini 0-1 arasında normalize et
y = to_categorical(labels, num_classes=len(np.unique(labels)))  # Etiketleri one-hot encode et

# Eğitim ve test setlerini oluştur
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Modeli oluşturma
model = Sequential([
    Input(shape=(30, 30, 3)),   # Görüntü boyutları (30x30x3)
    Flatten(),                  # Görüntüyü düzleştir
    RBFLayer(num_units=100, gamma=0.001),  # RBF katmanı
    Dense(len(y[0]), activation='softmax')  # Çıktı katmanı (sınıf sayısı kadar)
])

# Modeli derleme
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# Modeli eğitme
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64)

# Test doğruluğunu değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test doğruluğu: {test_acc:.2f}")
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 114s 261ms/step - accuracy: 0.0507 - loss: 3.6873 - val_accuracy: 0.0499 - val_loss: 3.4993
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 92s 215ms/step - accuracy: 0.0564 - loss: 3.4990 - val_accuracy: 0.0553 - val_loss: 3.4964
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 153s 240ms/step - accuracy: 0.0592 - loss: 3.4968 - val_accuracy: 0.0625 - val_loss: 3.4923
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 93s 217ms/step - accuracy: 0.0643 - loss: 3.4922 - val_accuracy: 0.0695 - val_loss: 3.4875
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 211ms/step - accuracy: 0.0680 - loss: 3.4998 - val_accuracy: 0.0666 - val_loss: 3.4870
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 214ms/step - accuracy: 0.0695 - loss: 3.4907 - val_accuracy: 0.0720 - val_loss: 3.4839
# Epoch 7/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 212ms/step - accuracy: 0.0727 - loss: 3.4841 - val_accuracy: 0.0720 - val_loss: 3.4830
# Epoch 8/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 215ms/step - accuracy: 0.0728 - loss: 3.4812 - val_accuracy: 0.0715 - val_loss: 3.4803
# Epoch 9/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 213ms/step - accuracy: 0.0703 - loss: 3.4867 - val_accuracy: 0.0752 - val_loss: 3.4787
# Epoch 10/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 216ms/step - accuracy: 0.0752 - loss: 3.4791 - val_accuracy: 0.0723 - val_loss: 3.4757
# Epoch 11/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 213ms/step - accuracy: 0.0776 - loss: 3.4787 - val_accuracy: 0.0748 - val_loss: 3.4724
# Epoch 12/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 214ms/step - accuracy: 0.0769 - loss: 3.4768 - val_accuracy: 0.0749 - val_loss: 3.4724
# Epoch 13/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 213ms/step - accuracy: 0.0793 - loss: 3.4701 - val_accuracy: 0.0712 - val_loss: 3.4697
# Epoch 14/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 217ms/step - accuracy: 0.0780 - loss: 3.4699 - val_accuracy: 0.0742 - val_loss: 3.4668
# Epoch 15/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 212ms/step - accuracy: 0.0790 - loss: 3.4637 - val_accuracy: 0.0775 - val_loss: 3.4653
# Epoch 16/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 153s 237ms/step - accuracy: 0.0816 - loss: 3.4670 - val_accuracy: 0.0777 - val_loss: 3.4631
# Epoch 17/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 131s 213ms/step - accuracy: 0.0792 - loss: 3.4627 - val_accuracy: 0.0771 - val_loss: 3.4621
# Epoch 18/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 152s 236ms/step - accuracy: 0.0776 - loss: 3.4582 - val_accuracy: 0.0821 - val_loss: 3.4606
# Epoch 19/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 132s 213ms/step - accuracy: 0.0796 - loss: 3.4622 - val_accuracy: 0.0806 - val_loss: 3.4613
# Epoch 20/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 217ms/step - accuracy: 0.0801 - loss: 3.4629 - val_accuracy: 0.0753 - val_loss: 3.4583
# Epoch 21/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 212ms/step - accuracy: 0.0792 - loss: 3.4554 - val_accuracy: 0.0769 - val_loss: 3.4584
# Epoch 22/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 212ms/step - accuracy: 0.0798 - loss: 3.4647 - val_accuracy: 0.0718 - val_loss: 3.4576
# Epoch 23/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 93s 216ms/step - accuracy: 0.0761 - loss: 3.4587 - val_accuracy: 0.0750 - val_loss: 3.4553
# Epoch 24/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 213ms/step - accuracy: 0.0811 - loss: 3.4586 - val_accuracy: 0.0821 - val_loss: 3.4514
# Epoch 25/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 215ms/step - accuracy: 0.0822 - loss: 3.4491 - val_accuracy: 0.0805 - val_loss: 3.4509
# Epoch 26/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 212ms/step - accuracy: 0.0821 - loss: 3.4626 - val_accuracy: 0.0821 - val_loss: 3.4499
# Epoch 27/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 212ms/step - accuracy: 0.0842 - loss: 3.4494 - val_accuracy: 0.0741 - val_loss: 3.4491
# Epoch 28/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 213ms/step - accuracy: 0.0833 - loss: 3.4489 - val_accuracy: 0.0813 - val_loss: 3.4481
# Epoch 29/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 213ms/step - accuracy: 0.0807 - loss: 3.4447 - val_accuracy: 0.0828 - val_loss: 3.4472
# Epoch 30/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 215ms/step - accuracy: 0.0800 - loss: 3.4482 - val_accuracy: 0.0793 - val_loss: 3.4469
# Epoch 31/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 213ms/step - accuracy: 0.0813 - loss: 3.4386 - val_accuracy: 0.0847 - val_loss: 3.4453
# Epoch 32/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 213ms/step - accuracy: 0.0846 - loss: 3.4459 - val_accuracy: 0.0792 - val_loss: 3.4436
# Epoch 33/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 215ms/step - accuracy: 0.0811 - loss: 3.4523 - val_accuracy: 0.0781 - val_loss: 3.4415
# Epoch 34/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 213ms/step - accuracy: 0.0841 - loss: 3.4407 - val_accuracy: 0.0782 - val_loss: 3.4426
# Epoch 35/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 213ms/step - accuracy: 0.0814 - loss: 3.4434 - val_accuracy: 0.0784 - val_loss: 3.4418
# Epoch 36/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 92s 215ms/step - accuracy: 0.0811 - loss: 3.4423 - val_accuracy: 0.0837 - val_loss: 3.4403
# Epoch 37/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 212ms/step - accuracy: 0.0815 - loss: 3.4414 - val_accuracy: 0.0804 - val_loss: 3.4405
# Epoch 38/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 216ms/step - accuracy: 0.0814 - loss: 3.4327 - val_accuracy: 0.0762 - val_loss: 3.4408
# Epoch 39/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 213ms/step - accuracy: 0.0781 - loss: 3.4425 - val_accuracy: 0.0838 - val_loss: 3.4371
# Epoch 40/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 212ms/step - accuracy: 0.0836 - loss: 3.4369 - val_accuracy: 0.0761 - val_loss: 3.4365
# Epoch 41/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 212ms/step - accuracy: 0.0826 - loss: 3.4405 - val_accuracy: 0.0815 - val_loss: 3.4366
# Epoch 42/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 214ms/step - accuracy: 0.0828 - loss: 3.4356 - val_accuracy: 0.0847 - val_loss: 3.4355
# Epoch 43/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 212ms/step - accuracy: 0.0859 - loss: 3.4334 - val_accuracy: 0.0780 - val_loss: 3.4342
# Epoch 44/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 216ms/step - accuracy: 0.0838 - loss: 3.4431 - val_accuracy: 0.0812 - val_loss: 3.4334
# Epoch 45/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 212ms/step - accuracy: 0.0848 - loss: 3.4316 - val_accuracy: 0.0808 - val_loss: 3.4347
# Epoch 46/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0862 - loss: 3.4284 - val_accuracy: 0.0847 - val_loss: 3.4321
# Epoch 47/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 212ms/step - accuracy: 0.0823 - loss: 3.4321 - val_accuracy: 0.0763 - val_loss: 3.4310
# Epoch 48/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 214ms/step - accuracy: 0.0834 - loss: 3.4284 - val_accuracy: 0.0843 - val_loss: 3.4311
# Epoch 49/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 213ms/step - accuracy: 0.0832 - loss: 3.4320 - val_accuracy: 0.0807 - val_loss: 3.4321
# Epoch 50/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 212ms/step - accuracy: 0.0851 - loss: 3.4293 - val_accuracy: 0.0822 - val_loss: 3.4303
# Epoch 51/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 215ms/step - accuracy: 0.0829 - loss: 3.4338 - val_accuracy: 0.0784 - val_loss: 3.4296
# Epoch 52/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 212ms/step - accuracy: 0.0832 - loss: 3.4300 - val_accuracy: 0.0812 - val_loss: 3.4310
# Epoch 53/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 212ms/step - accuracy: 0.0829 - loss: 3.4307 - val_accuracy: 0.0808 - val_loss: 3.4296
# Epoch 54/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 211ms/step - accuracy: 0.0822 - loss: 3.4225 - val_accuracy: 0.0849 - val_loss: 3.4291
# Epoch 55/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 153s 237ms/step - accuracy: 0.0843 - loss: 3.4237 - val_accuracy: 0.0865 - val_loss: 3.4283
# Epoch 56/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 131s 212ms/step - accuracy: 0.0858 - loss: 3.4298 - val_accuracy: 0.0849 - val_loss: 3.4287
# Epoch 57/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 90s 210ms/step - accuracy: 0.0832 - loss: 3.4347 - val_accuracy: 0.0837 - val_loss: 3.4259
# Epoch 58/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 213ms/step - accuracy: 0.0820 - loss: 3.4324 - val_accuracy: 0.0812 - val_loss: 3.4266
# Epoch 59/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 150s 231ms/step - accuracy: 0.0845 - loss: 3.4274 - val_accuracy: 0.0862 - val_loss: 3.4264
# Epoch 60/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 90s 210ms/step - accuracy: 0.0867 - loss: 3.4216 - val_accuracy: 0.0795 - val_loss: 3.4260
# Epoch 61/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 213ms/step - accuracy: 0.0859 - loss: 3.4311 - val_accuracy: 0.0803 - val_loss: 3.4247
# Epoch 62/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 210ms/step - accuracy: 0.0840 - loss: 3.4259 - val_accuracy: 0.0805 - val_loss: 3.4253
# Epoch 63/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 213ms/step - accuracy: 0.0830 - loss: 3.4214 - val_accuracy: 0.0820 - val_loss: 3.4241
# Epoch 64/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 210ms/step - accuracy: 0.0849 - loss: 3.4183 - val_accuracy: 0.0781 - val_loss: 3.4249
# Epoch 65/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 90s 211ms/step - accuracy: 0.0874 - loss: 3.4258 - val_accuracy: 0.0856 - val_loss: 3.4228
# Epoch 66/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0869 - loss: 3.4265 - val_accuracy: 0.0784 - val_loss: 3.4241
# Epoch 67/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 90s 210ms/step - accuracy: 0.0805 - loss: 3.4281 - val_accuracy: 0.0858 - val_loss: 3.4228
# Epoch 68/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 213ms/step - accuracy: 0.0812 - loss: 3.4218 - val_accuracy: 0.0855 - val_loss: 3.4221
# Epoch 69/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 211ms/step - accuracy: 0.0852 - loss: 3.4206 - val_accuracy: 0.0798 - val_loss: 3.4209
# Epoch 70/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 214ms/step - accuracy: 0.0846 - loss: 3.4197 - val_accuracy: 0.0803 - val_loss: 3.4215
# Epoch 71/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 211ms/step - accuracy: 0.0860 - loss: 3.4172 - val_accuracy: 0.0740 - val_loss: 3.4238
# Epoch 72/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 216ms/step - accuracy: 0.0850 - loss: 3.4202 - val_accuracy: 0.0794 - val_loss: 3.4198
# Epoch 73/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 211ms/step - accuracy: 0.0804 - loss: 3.4212 - val_accuracy: 0.0736 - val_loss: 3.4222
# Epoch 74/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 215ms/step - accuracy: 0.0821 - loss: 3.4153 - val_accuracy: 0.0865 - val_loss: 3.4205
# Epoch 75/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 212ms/step - accuracy: 0.0847 - loss: 3.4202 - val_accuracy: 0.0745 - val_loss: 3.4217
# Epoch 76/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 211ms/step - accuracy: 0.0865 - loss: 3.4083 - val_accuracy: 0.0797 - val_loss: 3.4216
# Epoch 77/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 92s 215ms/step - accuracy: 0.0828 - loss: 3.4284 - val_accuracy: 0.0810 - val_loss: 3.4184
# Epoch 78/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 212ms/step - accuracy: 0.0852 - loss: 3.4243 - val_accuracy: 0.0873 - val_loss: 3.4198
# Epoch 79/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0843 - loss: 3.4235 - val_accuracy: 0.0831 - val_loss: 3.4172
# Epoch 80/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0838 - loss: 3.4194 - val_accuracy: 0.0809 - val_loss: 3.4178
# Epoch 81/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0825 - loss: 3.4154 - val_accuracy: 0.0860 - val_loss: 3.4204
# Epoch 82/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 213ms/step - accuracy: 0.0869 - loss: 3.4158 - val_accuracy: 0.0808 - val_loss: 3.4192
# Epoch 83/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 210ms/step - accuracy: 0.0820 - loss: 3.4177 - val_accuracy: 0.0848 - val_loss: 3.4201
# Epoch 84/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 213ms/step - accuracy: 0.0831 - loss: 3.4208 - val_accuracy: 0.0859 - val_loss: 3.4182
# Epoch 85/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 210ms/step - accuracy: 0.0876 - loss: 3.4148 - val_accuracy: 0.0864 - val_loss: 3.4167
# Epoch 86/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 214ms/step - accuracy: 0.0821 - loss: 3.4197 - val_accuracy: 0.0844 - val_loss: 3.4168
# Epoch 87/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 210ms/step - accuracy: 0.0875 - loss: 3.4104 - val_accuracy: 0.0741 - val_loss: 3.4170
# Epoch 88/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 90s 210ms/step - accuracy: 0.0847 - loss: 3.4154 - val_accuracy: 0.0785 - val_loss: 3.4174
# Epoch 89/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 212ms/step - accuracy: 0.0828 - loss: 3.4154 - val_accuracy: 0.0843 - val_loss: 3.4170
# Epoch 90/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 90s 211ms/step - accuracy: 0.0857 - loss: 3.4082 - val_accuracy: 0.0892 - val_loss: 3.4171
# Epoch 91/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 210ms/step - accuracy: 0.0840 - loss: 3.4174 - val_accuracy: 0.0844 - val_loss: 3.4160
# Epoch 92/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0858 - loss: 3.4188 - val_accuracy: 0.0785 - val_loss: 3.4170
# Epoch 93/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0824 - loss: 3.4251 - val_accuracy: 0.0857 - val_loss: 3.4159
# Epoch 94/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 211ms/step - accuracy: 0.0832 - loss: 3.4139 - val_accuracy: 0.0825 - val_loss: 3.4151
# Epoch 95/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 214ms/step - accuracy: 0.0863 - loss: 3.4109 - val_accuracy: 0.0862 - val_loss: 3.4148
# Epoch 96/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 212ms/step - accuracy: 0.0881 - loss: 3.4155 - val_accuracy: 0.0824 - val_loss: 3.4156
# Epoch 97/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 211ms/step - accuracy: 0.0857 - loss: 3.4177 - val_accuracy: 0.0790 - val_loss: 3.4165
# Epoch 98/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 92s 214ms/step - accuracy: 0.0871 - loss: 3.4155 - val_accuracy: 0.0853 - val_loss: 3.4171
# Epoch 99/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 211ms/step - accuracy: 0.0827 - loss: 3.4178 - val_accuracy: 0.0885 - val_loss: 3.4144
# Epoch 100/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 91s 212ms/step - accuracy: 0.0836 - loss: 3.4170 - val_accuracy: 0.0854 - val_loss: 3.4141
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.0860 - loss: 3.4109
# Test doğruluğu: 0.09

# %%
def create_model(num_units=100, gamma=0.1, optimizer='adam'):
    model = Sequential([
        Input(shape=(30, 30, 3)),   # Görüntü boyutları (30x30x3)
        Flatten(),                  # Görüntüyü düzleştir
        RBFLayer(num_units=num_units, gamma=gamma),  # RBF katmanı
        Dense(len(y_train[0]), activation='softmax')  # Çıktı katmanı (sınıf sayısı kadar)
    ])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

#Modeli bir KerasClassifier içine sarmalayarak, Scikit-learn’ün arama metodlarıyla uyumlu hale getiriyoruz.
keras_model = KerasClassifier(model=create_model, verbose=0)

#Hiperparametre Alanı ve RandomizedSearchCV
#Hiperparametreler için arama alanını belirliyoruz. Burada num_units, gamma, optimizer, batch_size, ve epochs
#gibi parametrelerin aralığını belirtebiliriz.

# Hiperparametre arama alanı
# Hiperparametre arama alanı
param_distributions = {
    'model__num_units': [50],            # RBF katmanı birim sayısı
    'model__gamma': [0.001],           # RBF gamma parametresi
    'model__optimizer': ['sgd'], # Farklı optimizasyon algoritmaları
    'batch_size': [32],            # Batch size
    'epochs': [10, 20]
}
"""
param_distributions = {
    'model__num_units': [50, 100, 150],            # RBF katmanı birim sayısı
    'model__gamma': [0.01, 0.1, 1, 10],           # RBF gamma parametresi
    'model__optimizer': ['adam', 'sgd', 'rmsprop'], # Farklı optimizasyon algoritmaları
    'batch_size': [32, 64, 128],            # Batch size
    'epochs': [10, 20]                      # Eğitim döngü sayısı
}
"""
#******************************************
# RandomizedSearchCV yapılandırma
random_search = RandomizedSearchCV(
    estimator=keras_model,
    param_distributions=param_distributions,
    n_iter=5,  # Arama yapılacak kombinasyon sayısı
    cv=3,       # 3 katlı çapraz doğrulama
    verbose=2,
    n_jobs=-1   # Paralel çalıştırma (tüm çekirdekler)
)
#Modeli Eğitme ve En İyi Sonuçları Bulma
#Arama işlemini başlatıyoruz ve en iyi parametre kombinasyonunu buluyoruz.
random_search.fit(X_train, y_train)

# En iyi parametreleri ve doğruluğu görüntüleme
print("En iyi parametreler:", random_search.best_params_)
print("En iyi doğruluk:", random_search.best_score_)

#Seçilen Parametrelerle Modeli Test Etme
#En iyi parametrelerle oluşturulan modeli test etmek için:

best_model = random_search.best_estimator_
test_loss, test_acc = best_model.model_.evaluate(X_test, y_test)
print(f"Test doğruluğu (optimized): {test_acc:.2f}")
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# En iyi parametreler: {'model__optimizer': 'sgd', 'model__num_units': 50, 'model__gamma': 0.001, 'epochs': 20, 'batch_size': 32}
# En iyi doğruluk: 0.08343654931158097
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.0817 - loss: 3.4345
# Test doğruluğu (optimized): 0.08

# %%
# Parameter grid for GridSearchCV
param_grid = {
    'model__num_units': [50, 100, 150],  # Updated: model__num_units
    'model__gamma': [0.1, 0.5, 1.0],  # Updated: model__gamma
}

# Create GridSearchCV object
grid_search = GridSearchCV(
    estimator=KerasClassifier(model=create_model), # Updated line
    param_grid=param_grid,
    cv=3,  # Number of cross-validation folds
    verbose=2,
)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and score
print("Best parameters found by GridSearchCV:", grid_search.best_params_)
print("Best score found by GridSearchCV:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.0652 - loss: 3.6700
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  21.6s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - accuracy: 0.0647 - loss: 3.6628
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  21.0s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.0632 - loss: 3.6596
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  20.9s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 49s 85ms/step - accuracy: 0.0706 - loss: 3.6628
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time=  58.8s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 50s 86ms/step - accuracy: 0.0763 - loss: 3.6489
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.0min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 50s 86ms/step - accuracy: 0.0727 - loss: 3.6506
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.0min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.0691 - loss: 3.6619
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 65ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 91s 157ms/step - accuracy: 0.0779 - loss: 3.6487
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 15s 54ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.0693 - loss: 3.6518
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.0543 - loss: 3.6989
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  24.9s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.0632 - loss: 3.7017
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  21.7s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.0533 - loss: 3.6980
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  21.3s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 50s 87ms/step - accuracy: 0.0599 - loss: 3.6978
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.0min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 53s 90ms/step - accuracy: 0.0584 - loss: 3.6978
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.5min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 44s 75ms/step - accuracy: 0.0596 - loss: 3.6943
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time=  55.5s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 83s 143ms/step - accuracy: 0.0597 - loss: 3.6985
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 86s 148ms/step - accuracy: 0.0631 - loss: 3.6944
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 2.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 86s 149ms/step - accuracy: 0.0543 - loss: 3.6930
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.0479 - loss: 3.7126
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  22.4s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.0504 - loss: 3.7130
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  23.0s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.0558 - loss: 3.7129
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  24.1s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 65s 112ms/step - accuracy: 0.0503 - loss: 3.7122
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.5min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 60s 103ms/step - accuracy: 0.0559 - loss: 3.7131
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.5min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 58s 101ms/step - accuracy: 0.0578 - loss: 3.7123
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 84s 146ms/step - accuracy: 0.0538 - loss: 3.7129
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 86s 148ms/step - accuracy: 0.0491 - loss: 3.7135
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 86s 148ms/step - accuracy: 0.0522 - loss: 3.7126
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.7min
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 132s 152ms/step - accuracy: 0.0774 - loss: 3.6261
# Best parameters found by GridSearchCV: {'model__gamma': 0.1, 'model__num_units': 150}
# Best score found by GridSearchCV: 0.09363829536780739
