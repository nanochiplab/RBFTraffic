# %% [markdown]
# <a href="https://colab.research.google.com/github/nanochiplab/RBFTraffic/blob/main/OdevTraffic_RBF_Gamma0_1_Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

import os
from keras.utils import load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout,Activation,InputLayer,Layer

import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
#!git clone https://github.com/sonu275981/GTSRB---German-Traffic-Sign-Recognition
#cur_path= "GTSRB---German-Traffic-Sign-Recognition/gtsrb-german-traffic-sign/Train/"
# !git clone https://github.com/MohamedNennouche/German-Traffic-Sign-Recognition
cur_path= "German-Traffic-Sign-Recognition/Train/"
# Out:
# fatal: destination path 'German-Traffic-Sign-Recognition' already exists and is not an empty directory.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#cur_path = "/content/drive/MyDrive/Mlp/Train"


data = []
labels = []
classes = 43  # Toplam sınıf sayısı

# Veri listeleri
X = []
y = []

print("")
print("Görüntüler Yükleniyor...")
print("************************........:")
print("")

# Görüntüleri yükleme

# Görüntüleri yükleme
for i in range(classes):
    path = os.path.join(cur_path, str(i))


    # Özyinelemeli olarak tüm dosyaları gez
    for root, dirs, files in os.walk(path):
        for file in files:
            try:
                image_path = os.path.join(root, file)

                # Görüntü dosyasını yükle ve işle
                image = Image.open(image_path)
                image = image.resize((30, 30))
                image = np.array(image)

                # Veri ve etiketleri ekle
                #data.append([image, i])
                data.append(image)
                labels.append(i)  # Etiketleri ayrı olarak ekleyin
            except Exception as e:
                print(f"Hata: Görüntü yüklenemedi. Dosya: {image_path}, Hata: {e}")

print(f"Toplam yüklenen görüntü sayısı: {len(data)}")
print("************************........:")

#x = []
#y = []
"""
X = []
y = []

for features,label in data:
    X.append(features)
    y.append(label)
"""
#Converting lists into numpy arrays
X = np.array(data)
y = np.array(labels)
# Out:
# Görüntüler Yükleniyor...
# ************************........:
#
# Toplam yüklenen görüntü sayısı: 39209
# ************************........:

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Layer, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Özel RBF katmanı tanımı
class RBFLayer(Layer):
    def __init__(self, num_units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.num_units = num_units
        self.gamma = gamma

    def build(self, input_shape):
        self.centers = self.add_weight(name='centers',
                                       shape=(self.num_units, input_shape[-1]),
                                       initializer='random_normal',
                                       trainable=True)
        self.built = True

    def call(self, inputs):
        # RBF fonksiyonu: exp(-gamma * ||inputs - centers||^2)
        diff = tf.expand_dims(inputs, axis=1) - self.centers
        sq_dist = tf.reduce_sum(tf.square(diff), axis=-1)
        return tf.exp(-self.gamma * sq_dist)

# Veriyi normalize etme ve sınıflara ayırma
X = X / 255.0  # Piksel değerlerini 0-1 arasında normalize et
y = to_categorical(labels, num_classes=len(np.unique(labels)))  # Etiketleri one-hot encode et

# Eğitim ve test setlerini oluştur
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Modeli oluşturma
model = Sequential([
    Input(shape=(30, 30, 3)),   # Görüntü boyutları (30x30x3)
    Flatten(),                  # Görüntüyü düzleştir
    RBFLayer(num_units=100, gamma=0.1),  # RBF katmanı
    Dense(len(y[0]), activation='softmax')  # Çıktı katmanı (sınıf sayısı kadar)
])

# Modeli derleme
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Modeli eğitme
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64)

# Test doğruluğunu değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test doğruluğu: {test_acc:.2f}")
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.0664 - loss: 3.6557 - val_accuracy: 0.0958 - val_loss: 3.4987
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0998 - loss: 3.4637 - val_accuracy: 0.1047 - val_loss: 3.3986
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1066 - loss: 3.3710 - val_accuracy: 0.1171 - val_loss: 3.3293
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1225 - loss: 3.3022 - val_accuracy: 0.1319 - val_loss: 3.2860
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1330 - loss: 3.2728 - val_accuracy: 0.1415 - val_loss: 3.2535
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1397 - loss: 3.2388 - val_accuracy: 0.1457 - val_loss: 3.2271
# Epoch 7/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1492 - loss: 3.2091 - val_accuracy: 0.1555 - val_loss: 3.2049
# Epoch 8/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1565 - loss: 3.1839 - val_accuracy: 0.1574 - val_loss: 3.1872
# Epoch 9/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1599 - loss: 3.1658 - val_accuracy: 0.1588 - val_loss: 3.1723
# Epoch 10/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1585 - loss: 3.1482 - val_accuracy: 0.1607 - val_loss: 3.1550
# Epoch 11/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1633 - loss: 3.1407 - val_accuracy: 0.1615 - val_loss: 3.1389
# Epoch 12/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1664 - loss: 3.1350 - val_accuracy: 0.1595 - val_loss: 3.1253
# Epoch 13/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1678 - loss: 3.1098 - val_accuracy: 0.1682 - val_loss: 3.1130
# Epoch 14/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1716 - loss: 3.1016 - val_accuracy: 0.1739 - val_loss: 3.1025
# Epoch 15/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1785 - loss: 3.0823 - val_accuracy: 0.1699 - val_loss: 3.0898
# Epoch 16/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1771 - loss: 3.0757 - val_accuracy: 0.1761 - val_loss: 3.0801
# Epoch 17/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1829 - loss: 3.0510 - val_accuracy: 0.1782 - val_loss: 3.0730
# Epoch 18/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1822 - loss: 3.0673 - val_accuracy: 0.1751 - val_loss: 3.0622
# Epoch 19/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.1832 - loss: 3.0462 - val_accuracy: 0.1792 - val_loss: 3.0518
# Epoch 20/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1906 - loss: 3.0228 - val_accuracy: 0.1846 - val_loss: 3.0400
# Epoch 21/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1906 - loss: 3.0241 - val_accuracy: 0.1907 - val_loss: 3.0336
# Epoch 22/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1929 - loss: 3.0095 - val_accuracy: 0.1933 - val_loss: 3.0240
# Epoch 23/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1962 - loss: 2.9987 - val_accuracy: 0.1926 - val_loss: 3.0158
# Epoch 24/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1968 - loss: 3.0002 - val_accuracy: 0.1965 - val_loss: 3.0093
# Epoch 25/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2008 - loss: 2.9872 - val_accuracy: 0.1916 - val_loss: 3.0031
# Epoch 26/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1997 - loss: 2.9802 - val_accuracy: 0.1956 - val_loss: 2.9947
# Epoch 27/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2029 - loss: 2.9791 - val_accuracy: 0.1940 - val_loss: 2.9894
# Epoch 28/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2014 - loss: 2.9767 - val_accuracy: 0.1972 - val_loss: 2.9826
# Epoch 29/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2085 - loss: 2.9618 - val_accuracy: 0.2022 - val_loss: 2.9731
# Epoch 30/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2062 - loss: 2.9726 - val_accuracy: 0.2028 - val_loss: 2.9678
# Epoch 31/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2146 - loss: 2.9500 - val_accuracy: 0.2077 - val_loss: 2.9598
# Epoch 32/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2126 - loss: 2.9379 - val_accuracy: 0.2115 - val_loss: 2.9541
# Epoch 33/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2221 - loss: 2.9225 - val_accuracy: 0.2127 - val_loss: 2.9465
# Epoch 34/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2179 - loss: 2.9254 - val_accuracy: 0.2138 - val_loss: 2.9400
# Epoch 35/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2139 - loss: 2.9341 - val_accuracy: 0.2145 - val_loss: 2.9347
# Epoch 36/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2218 - loss: 2.9085 - val_accuracy: 0.2173 - val_loss: 2.9291
# Epoch 37/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2206 - loss: 2.9202 - val_accuracy: 0.2167 - val_loss: 2.9255
# Epoch 38/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.2251 - loss: 2.9054 - val_accuracy: 0.2192 - val_loss: 2.9185
# Epoch 39/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2280 - loss: 2.8949 - val_accuracy: 0.2203 - val_loss: 2.9113
# Epoch 40/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2261 - loss: 2.8995 - val_accuracy: 0.2238 - val_loss: 2.9057
# Epoch 41/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2305 - loss: 2.8885 - val_accuracy: 0.2235 - val_loss: 2.9033
# Epoch 42/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2275 - loss: 2.8919 - val_accuracy: 0.2280 - val_loss: 2.8957
# Epoch 43/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2302 - loss: 2.8750 - val_accuracy: 0.2286 - val_loss: 2.8914
# Epoch 44/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2281 - loss: 2.8832 - val_accuracy: 0.2294 - val_loss: 2.8855
# Epoch 45/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2370 - loss: 2.8570 - val_accuracy: 0.2296 - val_loss: 2.8831
# Epoch 46/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2374 - loss: 2.8591 - val_accuracy: 0.2294 - val_loss: 2.8761
# Epoch 47/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2372 - loss: 2.8607 - val_accuracy: 0.2322 - val_loss: 2.8717
# Epoch 48/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2371 - loss: 2.8641 - val_accuracy: 0.2334 - val_loss: 2.8692
# Epoch 49/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2365 - loss: 2.8550 - val_accuracy: 0.2342 - val_loss: 2.8670
# Epoch 50/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2413 - loss: 2.8505 - val_accuracy: 0.2326 - val_loss: 2.8602
# Epoch 51/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2456 - loss: 2.8405 - val_accuracy: 0.2385 - val_loss: 2.8598
# Epoch 52/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2434 - loss: 2.8382 - val_accuracy: 0.2428 - val_loss: 2.8498
# Epoch 53/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2465 - loss: 2.8318 - val_accuracy: 0.2370 - val_loss: 2.8478
# Epoch 54/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2484 - loss: 2.8276 - val_accuracy: 0.2408 - val_loss: 2.8443
# Epoch 55/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2472 - loss: 2.8271 - val_accuracy: 0.2425 - val_loss: 2.8379
# Epoch 56/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2517 - loss: 2.8050 - val_accuracy: 0.2438 - val_loss: 2.8334
# Epoch 57/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2533 - loss: 2.8147 - val_accuracy: 0.2434 - val_loss: 2.8327
# Epoch 58/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2473 - loss: 2.8260 - val_accuracy: 0.2482 - val_loss: 2.8283
# Epoch 59/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2524 - loss: 2.8136 - val_accuracy: 0.2466 - val_loss: 2.8202
# Epoch 60/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2571 - loss: 2.8041 - val_accuracy: 0.2468 - val_loss: 2.8247
# Epoch 61/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2513 - loss: 2.8047 - val_accuracy: 0.2551 - val_loss: 2.8153
# Epoch 62/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2583 - loss: 2.7901 - val_accuracy: 0.2493 - val_loss: 2.8127
# Epoch 63/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2535 - loss: 2.7967 - val_accuracy: 0.2525 - val_loss: 2.8077
# Epoch 64/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2611 - loss: 2.7870 - val_accuracy: 0.2557 - val_loss: 2.8058
# Epoch 65/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2588 - loss: 2.8031 - val_accuracy: 0.2539 - val_loss: 2.8007
# Epoch 66/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2616 - loss: 2.7776 - val_accuracy: 0.2561 - val_loss: 2.7964
# Epoch 67/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2660 - loss: 2.7722 - val_accuracy: 0.2540 - val_loss: 2.7945
# Epoch 68/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2636 - loss: 2.7699 - val_accuracy: 0.2578 - val_loss: 2.7900
# Epoch 69/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2658 - loss: 2.7718 - val_accuracy: 0.2583 - val_loss: 2.7860
# Epoch 70/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2651 - loss: 2.7597 - val_accuracy: 0.2619 - val_loss: 2.7820
# Epoch 71/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2678 - loss: 2.7564 - val_accuracy: 0.2604 - val_loss: 2.7792
# Epoch 72/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2715 - loss: 2.7507 - val_accuracy: 0.2657 - val_loss: 2.7755
# Epoch 73/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2741 - loss: 2.7527 - val_accuracy: 0.2647 - val_loss: 2.7716
# Epoch 74/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2716 - loss: 2.7404 - val_accuracy: 0.2673 - val_loss: 2.7668
# Epoch 75/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2750 - loss: 2.7442 - val_accuracy: 0.2643 - val_loss: 2.7693
# Epoch 76/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2664 - loss: 2.7598 - val_accuracy: 0.2638 - val_loss: 2.7646
# Epoch 77/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2702 - loss: 2.7477 - val_accuracy: 0.2683 - val_loss: 2.7597
# Epoch 78/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2752 - loss: 2.7323 - val_accuracy: 0.2692 - val_loss: 2.7540
# Epoch 79/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2733 - loss: 2.7465 - val_accuracy: 0.2735 - val_loss: 2.7528
# Epoch 80/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2772 - loss: 2.7324 - val_accuracy: 0.2670 - val_loss: 2.7523
# Epoch 81/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2833 - loss: 2.7177 - val_accuracy: 0.2738 - val_loss: 2.7476
# Epoch 82/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2769 - loss: 2.7311 - val_accuracy: 0.2736 - val_loss: 2.7423
# Epoch 83/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2766 - loss: 2.7164 - val_accuracy: 0.2739 - val_loss: 2.7397
# Epoch 84/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2748 - loss: 2.7240 - val_accuracy: 0.2776 - val_loss: 2.7377
# Epoch 85/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2782 - loss: 2.7164 - val_accuracy: 0.2716 - val_loss: 2.7370
# Epoch 86/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2820 - loss: 2.7126 - val_accuracy: 0.2769 - val_loss: 2.7315
# Epoch 87/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2769 - loss: 2.7149 - val_accuracy: 0.2777 - val_loss: 2.7315
# Epoch 88/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2824 - loss: 2.7127 - val_accuracy: 0.2787 - val_loss: 2.7272
# Epoch 89/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2810 - loss: 2.7074 - val_accuracy: 0.2771 - val_loss: 2.7253
# Epoch 90/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2842 - loss: 2.7061 - val_accuracy: 0.2782 - val_loss: 2.7241
# Epoch 91/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2792 - loss: 2.7145 - val_accuracy: 0.2799 - val_loss: 2.7214
# Epoch 92/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2862 - loss: 2.6918 - val_accuracy: 0.2856 - val_loss: 2.7140
# Epoch 93/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2872 - loss: 2.6993 - val_accuracy: 0.2851 - val_loss: 2.7120
# Epoch 94/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2860 - loss: 2.6971 - val_accuracy: 0.2804 - val_loss: 2.7148
# Epoch 95/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2864 - loss: 2.6900 - val_accuracy: 0.2863 - val_loss: 2.7084
# Epoch 96/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2912 - loss: 2.6917 - val_accuracy: 0.2890 - val_loss: 2.7049
# Epoch 97/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.2910 - loss: 2.6832 - val_accuracy: 0.2884 - val_loss: 2.7042
# Epoch 98/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2948 - loss: 2.6714 - val_accuracy: 0.2837 - val_loss: 2.7041
# Epoch 99/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.2859 - loss: 2.6891 - val_accuracy: 0.2890 - val_loss: 2.6979
# Epoch 100/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2910 - loss: 2.6804 - val_accuracy: 0.2873 - val_loss: 2.6982
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2946 - loss: 2.6772
# Test doğruluğu: 0.29

# %%
def create_model(num_units=100, gamma=0.1, optimizer='adam'):
    model = Sequential([
        Input(shape=(30, 30, 3)),   # Görüntü boyutları (30x30x3)
        Flatten(),                  # Görüntüyü düzleştir
        RBFLayer(num_units=num_units, gamma=gamma),  # RBF katmanı
        Dense(len(y_train[0]), activation='softmax')  # Çıktı katmanı (sınıf sayısı kadar)
    ])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

#Modeli bir KerasClassifier içine sarmalayarak, Scikit-learn’ün arama metodlarıyla uyumlu hale getiriyoruz.
keras_model = KerasClassifier(model=create_model, verbose=0)

#Hiperparametre Alanı ve RandomizedSearchCV
#Hiperparametreler için arama alanını belirliyoruz. Burada num_units, gamma, optimizer, batch_size, ve epochs
#gibi parametrelerin aralığını belirtebiliriz.

# Hiperparametre arama alanı
# Hiperparametre arama alanı
param_distributions = {
    'model__num_units': [50],            # RBF katmanı birim sayısı
    'model__gamma': [0.1],           # RBF gamma parametresi
    'model__optimizer': ['adam'], # Farklı optimizasyon algoritmaları
    'batch_size': [64],            # Batch size
    'epochs': [100, 100]
}
"""
param_distributions = {
    'model__num_units': [50, 100, 150],            # RBF katmanı birim sayısı
    'model__gamma': [0.01, 0.1, 1, 10],           # RBF gamma parametresi
    'model__optimizer': ['adam', 'sgd', 'rmsprop'], # Farklı optimizasyon algoritmaları
    'batch_size': [32, 64, 128],            # Batch size
    'epochs': [10, 20]                      # Eğitim döngü sayısı
}
"""
#******************************************
# RandomizedSearchCV yapılandırma
random_search = RandomizedSearchCV(
    estimator=keras_model,
    param_distributions=param_distributions,
    n_iter=5,  # Arama yapılacak kombinasyon sayısı
    cv=3,       # 3 katlı çapraz doğrulama
    verbose=2,
    n_jobs=-1   # Paralel çalıştırma (tüm çekirdekler)
)
#Modeli Eğitme ve En İyi Sonuçları Bulma
#Arama işlemini başlatıyoruz ve en iyi parametre kombinasyonunu buluyoruz.
random_search.fit(X_train, y_train)

# En iyi parametreleri ve doğruluğu görüntüleme
print("En iyi parametreler:", random_search.best_params_)
print("En iyi doğruluk:", random_search.best_score_)

#Seçilen Parametrelerle Modeli Test Etme
#En iyi parametrelerle oluşturulan modeli test etmek için:

best_model = random_search.best_estimator_
test_loss, test_acc = best_model.model_.evaluate(X_test, y_test)
print(f"Test doğruluğu (optimized): {test_acc:.2f}")
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 2 is smaller than n_iter=5. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# En iyi parametreler: {'model__optimizer': 'adam', 'model__num_units': 50, 'model__gamma': 0.1, 'epochs': 100, 'batch_size': 64}
# En iyi doğruluk: 0.20913818577152365
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2404 - loss: 2.8432
# Test doğruluğu (optimized): 0.23

# %%
# Parameter grid for GridSearchCV
param_grid = {
    'model__num_units': [50, 100, 150],  # Updated: model__num_units
    'model__gamma': [0.1, 0.5, 1.0],  # Updated: model__gamma
}

# Create GridSearchCV object
grid_search = GridSearchCV(
    estimator=KerasClassifier(model=create_model), # Updated line
    param_grid=param_grid,
    cv=3,  # Number of cross-validation folds
    verbose=2,
)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and score
print("Best parameters found by GridSearchCV:", grid_search.best_params_)
print("Best score found by GridSearchCV:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.0704 - loss: 3.6683
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  20.4s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.0776 - loss: 3.6585
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  25.2s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.0716 - loss: 3.6603
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  23.5s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 60s 103ms/step - accuracy: 0.0710 - loss: 3.6588
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 61s 106ms/step - accuracy: 0.0715 - loss: 3.6559
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.2min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 64s 110ms/step - accuracy: 0.0708 - loss: 3.6521
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.2min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.0716 - loss: 3.6585
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 1.8min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 91s 158ms/step - accuracy: 0.0725 - loss: 3.6511
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 87s 150ms/step - accuracy: 0.0722 - loss: 3.6499
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.0580 - loss: 3.7006
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  19.7s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.0604 - loss: 3.6996
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  27.3s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0620 - loss: 3.6945
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  18.6s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 59s 103ms/step - accuracy: 0.0628 - loss: 3.6975
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.2min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 57s 99ms/step - accuracy: 0.0614 - loss: 3.6943
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 56s 96ms/step - accuracy: 0.0571 - loss: 3.6939
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 93s 162ms/step - accuracy: 0.0634 - loss: 3.6979
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 87s 151ms/step - accuracy: 0.0617 - loss: 3.6921
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 82s 142ms/step - accuracy: 0.0601 - loss: 3.6952
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0566 - loss: 3.7125
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  17.9s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0515 - loss: 3.7120
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  27.9s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0518 - loss: 3.7138
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  25.1s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 59s 102ms/step - accuracy: 0.0554 - loss: 3.7130
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 49s 84ms/step - accuracy: 0.0557 - loss: 3.7123
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 59s 103ms/step - accuracy: 0.0562 - loss: 3.7129
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 91s 157ms/step - accuracy: 0.0561 - loss: 3.7135
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 86s 148ms/step - accuracy: 0.0563 - loss: 3.7126
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 1.8min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.0512 - loss: 3.7128
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.6min
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 136s 157ms/step - accuracy: 0.0783 - loss: 3.6237
# Best parameters found by GridSearchCV: {'model__gamma': 0.1, 'model__num_units': 150}
# Best score found by GridSearchCV: 0.09764630610023001
