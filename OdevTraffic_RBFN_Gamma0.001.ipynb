# %% [markdown]
# <a href="https://colab.research.google.com/github/nanochiplab/RBFTraffic/blob/main/OdevTraffic_RBFN_Gamma0.001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

import os
from keras.utils import load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout,Activation,InputLayer,Layer

import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
#!git clone https://github.com/sonu275981/GTSRB---German-Traffic-Sign-Recognition
#cur_path= "GTSRB---German-Traffic-Sign-Recognition/gtsrb-german-traffic-sign/Train/"
# !git clone https://github.com/MohamedNennouche/German-Traffic-Sign-Recognition
cur_path= "German-Traffic-Sign-Recognition/Train/"
# Out:
# Cloning into 'German-Traffic-Sign-Recognition'...
# remote: Enumerating objects: 52027, done.
# remote: Total 52027 (delta 0), reused 0 (delta 0), pack-reused 52027 (from 1)
# Receiving objects: 100% (52027/52027), 300.65 MiB | 37.02 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Updating files: 100% (101736/101736), done.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#cur_path = "/content/drive/MyDrive/Mlp/Train"


data = []
labels = []
classes = 43  # Toplam sınıf sayısı

# Veri listeleri
X = []
y = []

print("")
print("Görüntüler Yükleniyor...")
print("************************........:")
print("")

# Görüntüleri yükleme

# Görüntüleri yükleme
for i in range(classes):
    path = os.path.join(cur_path, str(i))


    # Özyinelemeli olarak tüm dosyaları gez
    for root, dirs, files in os.walk(path):
        for file in files:
            try:
                image_path = os.path.join(root, file)

                # Görüntü dosyasını yükle ve işle
                image = Image.open(image_path)
                image = image.resize((30, 30))
                image = np.array(image)

                # Veri ve etiketleri ekle
                #data.append([image, i])
                data.append(image)
                labels.append(i)  # Etiketleri ayrı olarak ekleyin
            except Exception as e:
                print(f"Hata: Görüntü yüklenemedi. Dosya: {image_path}, Hata: {e}")

print(f"Toplam yüklenen görüntü sayısı: {len(data)}")
print("************************........:")

#x = []
#y = []
"""
X = []
y = []

for features,label in data:
    X.append(features)
    y.append(label)
"""
#Converting lists into numpy arrays
X = np.array(data)
y = np.array(labels)
# Out:
# Görüntüler Yükleniyor...
# ************************........:
#
# Toplam yüklenen görüntü sayısı: 39209
# ************************........:

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Downloading scikeras-0.13.0-py3-none-any.whl (26 kB)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.13.0

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Layer, Flatten
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Özel RBF katmanı tanımı
class RBFLayer(Layer):
    def __init__(self, num_units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.num_units = num_units
        self.gamma = gamma

    def build(self, input_shape):
        self.centers = self.add_weight(name='centers',
                                       shape=(self.num_units, input_shape[-1]),
                                       initializer='random_normal',
                                       trainable=True)
        self.built = True

    def call(self, inputs):
        # RBF fonksiyonu: exp(-gamma * ||inputs - centers||^2)
        diff = tf.expand_dims(inputs, axis=1) - self.centers
        sq_dist = tf.reduce_sum(tf.square(diff), axis=-1)
        return tf.exp(-self.gamma * sq_dist)

# Veriyi normalize etme ve sınıflara ayırma
X = X / 255.0  # Piksel değerlerini 0-1 arasında normalize et
y = to_categorical(labels, num_classes=len(np.unique(labels)))  # Etiketleri one-hot encode et

# Eğitim ve test setlerini oluştur
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Modeli oluşturma
model = Sequential([
    Input(shape=(30, 30, 3)),   # Görüntü boyutları (30x30x3)
    Flatten(),                  # Görüntüyü düzleştir
    RBFLayer(num_units=100, gamma=0.1),  # RBF katmanı
    Dense(len(y[0]), activation='softmax')  # Çıktı katmanı (sınıf sayısı kadar)
])

# Modeli derleme
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Modeli eğitme
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64)

# Test doğruluğunu değerlendirme
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test doğruluğu: {test_acc:.2f}")
# Out:
# Epoch 1/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 111s 252ms/step - accuracy: 0.0716 - loss: 3.6638 - val_accuracy: 0.1020 - val_loss: 3.4915
# Epoch 2/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 126s 216ms/step - accuracy: 0.0973 - loss: 3.4602 - val_accuracy: 0.1168 - val_loss: 3.3921
# Epoch 3/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 92s 213ms/step - accuracy: 0.1087 - loss: 3.3773 - val_accuracy: 0.1259 - val_loss: 3.3262
# Epoch 4/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 154s 243ms/step - accuracy: 0.1210 - loss: 3.3175 - val_accuracy: 0.1332 - val_loss: 3.2831
# Epoch 5/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 133s 222ms/step - accuracy: 0.1277 - loss: 3.2720 - val_accuracy: 0.1393 - val_loss: 3.2497
# Epoch 6/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 149s 238ms/step - accuracy: 0.1376 - loss: 3.2317 - val_accuracy: 0.1461 - val_loss: 3.2258
# Epoch 7/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 136s 224ms/step - accuracy: 0.1456 - loss: 3.2098 - val_accuracy: 0.1546 - val_loss: 3.2037
# Epoch 8/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 153s 250ms/step - accuracy: 0.1513 - loss: 3.1827 - val_accuracy: 0.1570 - val_loss: 3.1851
# Epoch 9/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 133s 230ms/step - accuracy: 0.1542 - loss: 3.1771 - val_accuracy: 0.1647 - val_loss: 3.1658
# Epoch 10/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 146s 240ms/step - accuracy: 0.1636 - loss: 3.1484 - val_accuracy: 0.1664 - val_loss: 3.1539
# Epoch 11/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 134s 222ms/step - accuracy: 0.1617 - loss: 3.1430 - val_accuracy: 0.1558 - val_loss: 3.1413
# Epoch 12/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 223ms/step - accuracy: 0.1636 - loss: 3.1267 - val_accuracy: 0.1726 - val_loss: 3.1227
# Epoch 13/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 104s 243ms/step - accuracy: 0.1649 - loss: 3.1066 - val_accuracy: 0.1759 - val_loss: 3.1128
# Epoch 14/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 100s 233ms/step - accuracy: 0.1756 - loss: 3.0850 - val_accuracy: 0.1733 - val_loss: 3.0994
# Epoch 15/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 135s 216ms/step - accuracy: 0.1715 - loss: 3.0940 - val_accuracy: 0.1693 - val_loss: 3.0904
# Epoch 16/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 99s 231ms/step - accuracy: 0.1695 - loss: 3.0788 - val_accuracy: 0.1762 - val_loss: 3.0772
# Epoch 17/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 94s 219ms/step - accuracy: 0.1747 - loss: 3.0668 - val_accuracy: 0.1794 - val_loss: 3.0654
# Epoch 18/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 215ms/step - accuracy: 0.1826 - loss: 3.0530 - val_accuracy: 0.1835 - val_loss: 3.0563
# Epoch 19/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 98s 228ms/step - accuracy: 0.1792 - loss: 3.0511 - val_accuracy: 0.1855 - val_loss: 3.0478
# Epoch 20/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 138s 218ms/step - accuracy: 0.1856 - loss: 3.0348 - val_accuracy: 0.1879 - val_loss: 3.0389
# Epoch 21/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 146s 228ms/step - accuracy: 0.1869 - loss: 3.0361 - val_accuracy: 0.1913 - val_loss: 3.0302
# Epoch 22/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 139s 222ms/step - accuracy: 0.1927 - loss: 3.0090 - val_accuracy: 0.1914 - val_loss: 3.0227
# Epoch 23/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 147s 235ms/step - accuracy: 0.1914 - loss: 3.0134 - val_accuracy: 0.1909 - val_loss: 3.0162
# Epoch 24/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 137s 223ms/step - accuracy: 0.1956 - loss: 2.9956 - val_accuracy: 0.1964 - val_loss: 3.0049
# Epoch 25/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 230ms/step - accuracy: 0.1950 - loss: 2.9867 - val_accuracy: 0.1982 - val_loss: 2.9973
# Epoch 26/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 139s 223ms/step - accuracy: 0.2011 - loss: 2.9868 - val_accuracy: 0.2033 - val_loss: 2.9925
# Epoch 27/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 224ms/step - accuracy: 0.2058 - loss: 2.9663 - val_accuracy: 0.2054 - val_loss: 2.9850
# Epoch 28/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 96s 223ms/step - accuracy: 0.2082 - loss: 2.9716 - val_accuracy: 0.2084 - val_loss: 2.9759
# Epoch 29/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 158s 260ms/step - accuracy: 0.2086 - loss: 2.9678 - val_accuracy: 0.2083 - val_loss: 2.9736
# Epoch 30/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 127s 225ms/step - accuracy: 0.2183 - loss: 2.9477 - val_accuracy: 0.2089 - val_loss: 2.9628
# Epoch 31/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 232ms/step - accuracy: 0.2172 - loss: 2.9376 - val_accuracy: 0.2128 - val_loss: 2.9574
# Epoch 32/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 97s 227ms/step - accuracy: 0.2143 - loss: 2.9423 - val_accuracy: 0.2175 - val_loss: 2.9502
# Epoch 33/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 225ms/step - accuracy: 0.2159 - loss: 2.9456 - val_accuracy: 0.2144 - val_loss: 2.9441
# Epoch 34/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 225ms/step - accuracy: 0.2175 - loss: 2.9360 - val_accuracy: 0.2168 - val_loss: 2.9373
# Epoch 35/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 234ms/step - accuracy: 0.2195 - loss: 2.9299 - val_accuracy: 0.2183 - val_loss: 2.9324
# Epoch 36/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 136s 220ms/step - accuracy: 0.2193 - loss: 2.9246 - val_accuracy: 0.2192 - val_loss: 2.9280
# Epoch 37/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 222ms/step - accuracy: 0.2251 - loss: 2.9162 - val_accuracy: 0.2248 - val_loss: 2.9247
# Epoch 38/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 217ms/step - accuracy: 0.2326 - loss: 2.8885 - val_accuracy: 0.2266 - val_loss: 2.9159
# Epoch 39/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 224ms/step - accuracy: 0.2304 - loss: 2.9028 - val_accuracy: 0.2232 - val_loss: 2.9152
# Epoch 40/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 92s 214ms/step - accuracy: 0.2341 - loss: 2.8859 - val_accuracy: 0.2265 - val_loss: 2.9036
# Epoch 41/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 219ms/step - accuracy: 0.2286 - loss: 2.8872 - val_accuracy: 0.2265 - val_loss: 2.9007
# Epoch 42/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 215ms/step - accuracy: 0.2302 - loss: 2.8870 - val_accuracy: 0.2264 - val_loss: 2.8988
# Epoch 43/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 148s 230ms/step - accuracy: 0.2338 - loss: 2.8784 - val_accuracy: 0.2310 - val_loss: 2.8895
# Epoch 44/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 93s 218ms/step - accuracy: 0.2366 - loss: 2.8708 - val_accuracy: 0.2266 - val_loss: 2.8872
# Epoch 45/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 94s 219ms/step - accuracy: 0.2335 - loss: 2.8763 - val_accuracy: 0.2339 - val_loss: 2.8808
# Epoch 46/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 216ms/step - accuracy: 0.2362 - loss: 2.8625 - val_accuracy: 0.2349 - val_loss: 2.8743
# Epoch 47/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 94s 218ms/step - accuracy: 0.2389 - loss: 2.8646 - val_accuracy: 0.2396 - val_loss: 2.8700
# Epoch 48/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 221ms/step - accuracy: 0.2378 - loss: 2.8689 - val_accuracy: 0.2401 - val_loss: 2.8659
# Epoch 49/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 218ms/step - accuracy: 0.2423 - loss: 2.8476 - val_accuracy: 0.2410 - val_loss: 2.8593
# Epoch 50/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 105s 244ms/step - accuracy: 0.2451 - loss: 2.8401 - val_accuracy: 0.2386 - val_loss: 2.8592
# Epoch 51/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 246ms/step - accuracy: 0.2514 - loss: 2.8233 - val_accuracy: 0.2418 - val_loss: 2.8536
# Epoch 52/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 133s 225ms/step - accuracy: 0.2492 - loss: 2.8265 - val_accuracy: 0.2459 - val_loss: 2.8478
# Epoch 53/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 228ms/step - accuracy: 0.2486 - loss: 2.8324 - val_accuracy: 0.2418 - val_loss: 2.8461
# Epoch 54/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 226ms/step - accuracy: 0.2467 - loss: 2.8347 - val_accuracy: 0.2441 - val_loss: 2.8394
# Epoch 55/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 225ms/step - accuracy: 0.2545 - loss: 2.8186 - val_accuracy: 0.2454 - val_loss: 2.8342
# Epoch 56/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 226ms/step - accuracy: 0.2543 - loss: 2.8143 - val_accuracy: 0.2452 - val_loss: 2.8316
# Epoch 57/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 221ms/step - accuracy: 0.2505 - loss: 2.8153 - val_accuracy: 0.2453 - val_loss: 2.8269
# Epoch 58/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 224ms/step - accuracy: 0.2551 - loss: 2.7976 - val_accuracy: 0.2478 - val_loss: 2.8239
# Epoch 59/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 219ms/step - accuracy: 0.2541 - loss: 2.8048 - val_accuracy: 0.2501 - val_loss: 2.8188
# Epoch 60/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 222ms/step - accuracy: 0.2553 - loss: 2.8023 - val_accuracy: 0.2510 - val_loss: 2.8162
# Epoch 61/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 95s 221ms/step - accuracy: 0.2551 - loss: 2.8063 - val_accuracy: 0.2514 - val_loss: 2.8114
# Epoch 62/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 217ms/step - accuracy: 0.2581 - loss: 2.7924 - val_accuracy: 0.2514 - val_loss: 2.8086
# Epoch 63/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 221ms/step - accuracy: 0.2596 - loss: 2.7839 - val_accuracy: 0.2527 - val_loss: 2.8063
# Epoch 64/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 222ms/step - accuracy: 0.2622 - loss: 2.7806 - val_accuracy: 0.2583 - val_loss: 2.8026
# Epoch 65/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 220ms/step - accuracy: 0.2604 - loss: 2.7832 - val_accuracy: 0.2555 - val_loss: 2.7962
# Epoch 66/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 227ms/step - accuracy: 0.2662 - loss: 2.7681 - val_accuracy: 0.2539 - val_loss: 2.7924
# Epoch 67/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 97s 226ms/step - accuracy: 0.2616 - loss: 2.7768 - val_accuracy: 0.2546 - val_loss: 2.7893
# Epoch 68/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 94s 218ms/step - accuracy: 0.2627 - loss: 2.7709 - val_accuracy: 0.2609 - val_loss: 2.7856
# Epoch 69/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 222ms/step - accuracy: 0.2633 - loss: 2.7760 - val_accuracy: 0.2589 - val_loss: 2.7868
# Epoch 70/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 224ms/step - accuracy: 0.2601 - loss: 2.7771 - val_accuracy: 0.2640 - val_loss: 2.7825
# Epoch 71/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 223ms/step - accuracy: 0.2678 - loss: 2.7522 - val_accuracy: 0.2629 - val_loss: 2.7812
# Epoch 72/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 222ms/step - accuracy: 0.2689 - loss: 2.7543 - val_accuracy: 0.2549 - val_loss: 2.7799
# Epoch 73/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 144s 226ms/step - accuracy: 0.2681 - loss: 2.7646 - val_accuracy: 0.2591 - val_loss: 2.7753
# Epoch 74/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 97s 227ms/step - accuracy: 0.2706 - loss: 2.7528 - val_accuracy: 0.2657 - val_loss: 2.7659
# Epoch 75/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 225ms/step - accuracy: 0.2688 - loss: 2.7494 - val_accuracy: 0.2689 - val_loss: 2.7651
# Epoch 76/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 98s 228ms/step - accuracy: 0.2740 - loss: 2.7408 - val_accuracy: 0.2677 - val_loss: 2.7613
# Epoch 77/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 225ms/step - accuracy: 0.2710 - loss: 2.7412 - val_accuracy: 0.2652 - val_loss: 2.7568
# Epoch 78/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 152s 248ms/step - accuracy: 0.2732 - loss: 2.7395 - val_accuracy: 0.2657 - val_loss: 2.7577
# Epoch 79/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 131s 222ms/step - accuracy: 0.2728 - loss: 2.7433 - val_accuracy: 0.2659 - val_loss: 2.7521
# Epoch 80/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 105s 244ms/step - accuracy: 0.2739 - loss: 2.7333 - val_accuracy: 0.2733 - val_loss: 2.7466
# Epoch 81/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 135s 227ms/step - accuracy: 0.2838 - loss: 2.7127 - val_accuracy: 0.2724 - val_loss: 2.7437
# Epoch 82/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 226ms/step - accuracy: 0.2788 - loss: 2.7249 - val_accuracy: 0.2676 - val_loss: 2.7481
# Epoch 83/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 143s 228ms/step - accuracy: 0.2771 - loss: 2.7246 - val_accuracy: 0.2720 - val_loss: 2.7423
# Epoch 84/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 138s 219ms/step - accuracy: 0.2819 - loss: 2.7080 - val_accuracy: 0.2763 - val_loss: 2.7351
# Epoch 85/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 97s 227ms/step - accuracy: 0.2816 - loss: 2.7092 - val_accuracy: 0.2733 - val_loss: 2.7368
# Epoch 86/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 137s 215ms/step - accuracy: 0.2822 - loss: 2.7026 - val_accuracy: 0.2767 - val_loss: 2.7305
# Epoch 87/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 221ms/step - accuracy: 0.2822 - loss: 2.7132 - val_accuracy: 0.2783 - val_loss: 2.7288
# Epoch 88/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 220ms/step - accuracy: 0.2868 - loss: 2.6975 - val_accuracy: 0.2810 - val_loss: 2.7263
# Epoch 89/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 151s 242ms/step - accuracy: 0.2838 - loss: 2.7082 - val_accuracy: 0.2792 - val_loss: 2.7243
# Epoch 90/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 134s 224ms/step - accuracy: 0.2920 - loss: 2.6870 - val_accuracy: 0.2776 - val_loss: 2.7241
# Epoch 91/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 95s 221ms/step - accuracy: 0.2829 - loss: 2.7001 - val_accuracy: 0.2834 - val_loss: 2.7198
# Epoch 92/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 146s 231ms/step - accuracy: 0.2853 - loss: 2.7020 - val_accuracy: 0.2770 - val_loss: 2.7164
# Epoch 93/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 97s 227ms/step - accuracy: 0.2845 - loss: 2.7086 - val_accuracy: 0.2793 - val_loss: 2.7126
# Epoch 94/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 139s 220ms/step - accuracy: 0.2912 - loss: 2.6848 - val_accuracy: 0.2816 - val_loss: 2.7124
# Epoch 95/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 140s 216ms/step - accuracy: 0.2897 - loss: 2.6911 - val_accuracy: 0.2807 - val_loss: 2.7081
# Epoch 96/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 142s 216ms/step - accuracy: 0.2912 - loss: 2.6874 - val_accuracy: 0.2822 - val_loss: 2.7053
# Epoch 97/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 94s 220ms/step - accuracy: 0.2862 - loss: 2.6956 - val_accuracy: 0.2824 - val_loss: 2.7064
# Epoch 98/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 93s 217ms/step - accuracy: 0.2863 - loss: 2.6835 - val_accuracy: 0.2816 - val_loss: 2.7004
# Epoch 99/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 141s 214ms/step - accuracy: 0.2912 - loss: 2.6888 - val_accuracy: 0.2878 - val_loss: 2.6991
# Epoch 100/100
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 145s 221ms/step - accuracy: 0.2917 - loss: 2.6819 - val_accuracy: 0.2859 - val_loss: 2.6973
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.2908 - loss: 2.6868
# Test doğruluğu: 0.29

# %%
def create_model(num_units=100, gamma=0.1, optimizer='adam'):
    model = Sequential([
        Input(shape=(30, 30, 3)),   # Görüntü boyutları (30x30x3)
        Flatten(),                  # Görüntüyü düzleştir
        RBFLayer(num_units=num_units, gamma=gamma),  # RBF katmanı
        Dense(len(y_train[0]), activation='softmax')  # Çıktı katmanı (sınıf sayısı kadar)
    ])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

#Modeli bir KerasClassifier içine sarmalayarak, Scikit-learn’ün arama metodlarıyla uyumlu hale getiriyoruz.
keras_model = KerasClassifier(model=create_model, verbose=0)

#Hiperparametre Alanı ve RandomizedSearchCV
#Hiperparametreler için arama alanını belirliyoruz. Burada num_units, gamma, optimizer, batch_size, ve epochs
#gibi parametrelerin aralığını belirtebiliriz.

# Hiperparametre arama alanı
# Hiperparametre arama alanı
param_distributions = {
    'model__num_units': [50],            # RBF katmanı birim sayısı
    'model__gamma': [0.01],           # RBF gamma parametresi
    'model__optimizer': ['adam'], # Farklı optimizasyon algoritmaları
    'batch_size': [32, 64, 128],            # Batch size
    'epochs': [10, 20]
}
"""
param_distributions = {
    'model__num_units': [50, 100, 150],            # RBF katmanı birim sayısı
    'model__gamma': [0.01, 0.1, 1, 10],           # RBF gamma parametresi
    'model__optimizer': ['adam', 'sgd', 'rmsprop'], # Farklı optimizasyon algoritmaları
    'batch_size': [32, 64, 128],            # Batch size
    'epochs': [10, 20]                      # Eğitim döngü sayısı
}
"""
#******************************************
# RandomizedSearchCV yapılandırma
random_search = RandomizedSearchCV(
    estimator=keras_model,
    param_distributions=param_distributions,
    n_iter=5,  # Arama yapılacak kombinasyon sayısı
    cv=3,       # 3 katlı çapraz doğrulama
    verbose=2,
    n_jobs=-1   # Paralel çalıştırma (tüm çekirdekler)
)
#Modeli Eğitme ve En İyi Sonuçları Bulma
#Arama işlemini başlatıyoruz ve en iyi parametre kombinasyonunu buluyoruz.
random_search.fit(X_train, y_train)

# En iyi parametreleri ve doğruluğu görüntüleme
print("En iyi parametreler:", random_search.best_params_)
print("En iyi doğruluk:", random_search.best_score_)

#Seçilen Parametrelerle Modeli Test Etme
#En iyi parametrelerle oluşturulan modeli test etmek için:

best_model = random_search.best_estimator_
test_loss, test_acc = best_model.model_.evaluate(X_test, y_test)
print(f"Test doğruluğu (optimized): {test_acc:.2f}")
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 1 is smaller than n_iter=5. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# En iyi parametreler: {'model__optimizer': 'adam', 'model__num_units': 50, 'model__gamma': 0.01}
# En iyi doğruluk: 0.0867885475475898
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.1042 - loss: 3.4202
# Test doğruluğu (optimized): 0.10

# %%
# Parameter grid for GridSearchCV
param_grid = {
    'model__num_units': [50, 100, 150],  # Updated: model__num_units
    'model__gamma': [0.1, 0.5, 1.0],  # Updated: model__gamma
}

# Create GridSearchCV object
grid_search = GridSearchCV(
    estimator=KerasClassifier(model=create_model), # Updated line
    param_grid=param_grid,
    cv=3,  # Number of cross-validation folds
    verbose=2,
)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and score
print("Best parameters found by GridSearchCV:", grid_search.best_params_)
print("Best score found by GridSearchCV:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.0704 - loss: 3.6683
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  20.4s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.0776 - loss: 3.6585
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  25.2s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.0716 - loss: 3.6603
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# [CV] END ..............model__gamma=0.1, model__num_units=50; total time=  23.5s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 60s 103ms/step - accuracy: 0.0710 - loss: 3.6588
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 61s 106ms/step - accuracy: 0.0715 - loss: 3.6559
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.2min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 64s 110ms/step - accuracy: 0.0708 - loss: 3.6521
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step
# [CV] END .............model__gamma=0.1, model__num_units=100; total time= 1.2min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.0716 - loss: 3.6585
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 1.8min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 91s 158ms/step - accuracy: 0.0725 - loss: 3.6511
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 87s 150ms/step - accuracy: 0.0722 - loss: 3.6499
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=0.1, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.0580 - loss: 3.7006
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  19.7s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - accuracy: 0.0604 - loss: 3.6996
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  27.3s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0620 - loss: 3.6945
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# [CV] END ..............model__gamma=0.5, model__num_units=50; total time=  18.6s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 59s 103ms/step - accuracy: 0.0628 - loss: 3.6975
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.2min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 57s 99ms/step - accuracy: 0.0614 - loss: 3.6943
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 56s 96ms/step - accuracy: 0.0571 - loss: 3.6939
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step
# [CV] END .............model__gamma=0.5, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 93s 162ms/step - accuracy: 0.0634 - loss: 3.6979
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 2.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 87s 151ms/step - accuracy: 0.0617 - loss: 3.6921
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 48ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 82s 142ms/step - accuracy: 0.0601 - loss: 3.6952
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step
# [CV] END .............model__gamma=0.5, model__num_units=150; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0566 - loss: 3.7125
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  17.9s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0515 - loss: 3.7120
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  27.9s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.0518 - loss: 3.7138
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# [CV] END ..............model__gamma=1.0, model__num_units=50; total time=  25.1s
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 59s 102ms/step - accuracy: 0.0554 - loss: 3.7130
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 49s 84ms/step - accuracy: 0.0557 - loss: 3.7123
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 59s 103ms/step - accuracy: 0.0562 - loss: 3.7129
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step
# [CV] END .............model__gamma=1.0, model__num_units=100; total time= 1.7min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 91s 157ms/step - accuracy: 0.0561 - loss: 3.7135
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.6min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 86s 148ms/step - accuracy: 0.0563 - loss: 3.7126
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 1.8min
# 572/572 ━━━━━━━━━━━━━━━━━━━━ 85s 147ms/step - accuracy: 0.0512 - loss: 3.7128
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 14s 50ms/step
# [CV] END .............model__gamma=1.0, model__num_units=150; total time= 2.6min
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 136s 157ms/step - accuracy: 0.0783 - loss: 3.6237
# Best parameters found by GridSearchCV: {'model__gamma': 0.1, 'model__num_units': 150}
# Best score found by GridSearchCV: 0.09764630610023001
